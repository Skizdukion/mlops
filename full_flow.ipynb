# %%
import pandas as pd
import os

train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

# %%
from utils.index import prep_house_price_data

(X_train_final, X_test_final, y_train, id_col) = prep_house_price_data(train_df, test_df)
# Out:
# Detected 21 skewed columns to fix.
#
# FIXED [MSSubClass]: Positive Skew (1.37) -> Applied Log1p
# FIXED [LotFrontage]: Positive Skew (1.10) -> Applied Log1p
# FIXED [LotArea]: Positive Skew (13.29) -> Applied Log1p
# FIXED [MasVnrArea]: Positive Skew (2.57) -> Applied Log1p
# FIXED [BsmtFinSF1]: Positive Skew (0.97) -> Applied Log1p
# FIXED [BsmtFinSF2]: Positive Skew (4.15) -> Applied Log1p
# FIXED [BsmtUnfSF]: Positive Skew (0.92) -> Applied Log1p
# FIXED [1stFlrSF]: Positive Skew (1.28) -> Applied Log1p
# FIXED [2ndFlrSF]: Positive Skew (0.84) -> Applied Log1p
# FIXED [LowQualFinSF]: Positive Skew (12.39) -> Applied Log1p
# FIXED [GrLivArea]: Positive Skew (1.00) -> Applied Log1p
# FIXED [BsmtHalfBath]: Positive Skew (3.94) -> Applied Log1p
# FIXED [KitchenAbvGr]: Positive Skew (4.29) -> Applied Log1p
# FIXED [GarageYrBlt]: Negative Skew (-3.90) -> Applied Yeo-Johnson
# FIXED [WoodDeckSF]: Positive Skew (1.86) -> Applied Log1p
# ...

# %%
from sklearn.model_selection import KFold, cross_val_score
import numpy as np


def rmse_cv(model, X, y):
    # Use K-Fold (k=10) for cross-validation
    kf = KFold(n_splits=10, shuffle=True, random_state=42).get_n_splits(X.values)

    # Calculate scores using cross-validation
    # Negative MSE is used as scoring, and the square root is taken for RMSE.
    rmse = np.sqrt(
        -cross_val_score(model, X.values, y, scoring="neg_mean_squared_error", cv=kf)
    )

    return rmse


print("RMSE cross-validation function (rmse_cv) defined.")
# Out:
# RMSE cross-validation function (rmse_cv) defined.

# %%
import xgboost as xgb


xgb_model = xgb.XGBRegressor(
    objective="reg:squarederror",  # Regression objective
    n_estimators=1000,  # Number of trees
    learning_rate=0.05,  # Learning rate
    max_depth=4,  # Maximum depth of a tree
    min_child_weight=1.5,  # Minimum child weight
    colsample_bytree=0.7,  # Column sampling ratio per tree
    subsample=0.7,  # Observation sampling ratio per tree
    random_state=42,  # For reproducibility
    n_jobs=-1,  # Use all cores
)

xgb_rmse = rmse_cv(xgb_model, X_train_final, y_train)

# %%
print(f"XGBoost RMSE (Cross-Validation Mean): {xgb_rmse.mean():.4f}") 
print(f"XGBoost RMSE (Standard Deviation): {xgb_rmse.std():.4f}")
# Out:
# XGBoost RMSE (Cross-Validation Mean): 0.1204
# XGBoost RMSE (Standard Deviation): 0.0221

# %%
# import xgboost as xgb
# from sklearn.linear_model import ElasticNet
# from sklearn.ensemble import RandomForestRegressor

# from utils.index import train

# en_model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)

# # xgb_model = xgb.XGBRegressor(
# #     n_estimators=1000,
# #     learning_rate=0.05,
# #     max_depth=5,
# #     subsample=0.8,
# #     colsample_bytree=0.8,
# #     n_jobs=-1,
# #     random_state=42,
# # )

# xgb_model = xgb.XGBRegressor(
#     objective="reg:squarederror",  # Regression objective
#     n_estimators=1000,  # Number of trees
#     learning_rate=0.05,  # Learning rate
#     max_depth=4,  # Maximum depth of a tree
#     min_child_weight=1.5,  # Minimum child weight
#     colsample_bytree=0.7,  # Column sampling ratio per tree
#     subsample=0.7,  # Observation sampling ratio per tree
#     random_state=42,  # For reproducibility
#     n_jobs=-1,  # Use all cores
# )

# rf_model = RandomForestRegressor(
#     n_estimators=500,
#     max_depth=10,
#     min_samples_split=5,
#     max_features="sqrt",
#     n_jobs=-1,
#     random_state=42,
# )

# en_model = train(en_model, X_train, y_train, X_val, y_val, train_constant["y_info"])
# rf_model = train(rf_model, X_train, y_train, X_val, y_val, train_constant["y_info"])
# xgb_model = train(xgb_model, X_train, y_train, X_val, y_val, train_constant["y_info"])

# %%
print(X_test_final.isna().sum()[X_test_final.isna().sum() > 0])
# Out:
# Series([], dtype: int64)

# %%
xgb_final = xgb_model.fit(X_train_final, y_train)

# %%
def export_submission(model, id_col):
    preds = model.predict(X_test_final)

    submission = pd.DataFrame({"Id": id_col, "SalePrice": np.exp(preds)})

    model_name = type(model).__name__
    submission.to_csv(f"{model_name}_submission.csv", index=False)


export_submission(xgb_model, id_col)
