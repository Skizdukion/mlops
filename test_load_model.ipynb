# %%
import pandas as pd
from utils.index import load_model_from_json, prep_df

# %%
loaded_model = load_model_from_json('model/trip_duration_model_v1.json')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

X_train, X_test, y_train, y_test = prep_df(
    [
        "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-01.parquet",
    ]
)

y_pred = loaded_model.predict(X_train)

rmse = mean_squared_error(y_train, y_pred)
mae = mean_absolute_error(y_train, y_pred)
r2 = r2_score(y_train, y_pred)

# MAE  : avg absolute error (typical mistake, same unit as y)
# RMSE : error magnitude, penalizes large mistakes (sensitive to outliers)
# R²   : % of variance explained vs predicting mean (1 = perfect)
print("RMSE:", rmse)
print("MAE:", mae)
print("R²:", r2)
# Good check: MAE << mean(y), RMSE < std(y)
# Out:
# RMSE: 7.048619202372901
# MAE: 1.3360172279173503
# R²: 0.9099518967299878
